# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r'/content/bank-additional-full_final (1).csv',sep=";")

# %%
data
# Out:
#         age        job  marital            education  default housing loan  \
# 0      56.0  housemaid  married             basic.4y       no      no   no
# 1      57.0   services  married          high.school  unknown      no   no
# 2      37.0   services  married          high.school       no     yes   no
# 3      40.0     admin.  married             basic.6y       no      no   no
# 4      56.0   services  married          high.school       no      no  yes
# ...     ...        ...      ...                  ...      ...     ...  ...
# 41194  74.0    retired  married  professional.course       no     yes   no
# 41195  74.0        NaN  married  professional.course       no     yes   no
# 41196  74.0    retired  married                  NaN       no     yes   no
# 41197   NaN        NaN      NaN                  NaN      NaN     NaN  NaN
# 41198  74.0    retired  married  professional.course       no     yes  NaN
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0      telephone   may         mon  ...       1.0  999.0       0.0
# 1      telephone   may         mon  ...       1.0  999.0       0.0
# 2      telephone   may         mon  ...       1.0  999.0       0.0
# 3      telephone   may         mon  ...       1.0  999.0       0.0
# 4      telephone   may         mon  ...       1.0  999.0       0.0
# ...          ...   ...         ...  ...       ...    ...       ...
# 41194   cellular   nov         fri  ...       3.0  999.0       1.0
# 41195   cellular   nov         fri  ...       3.0  999.0       1.0
# 41196   cellular   nov         fri  ...       3.0  999.0       1.0
# 41197        NaN   NaN         NaN  ...       NaN    NaN       NaN
# 41198   cellular   nov         fri  ...       3.0  999.0       1.0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0      nonexistent          1.1          93.994          -36.4      4.857
# 1      nonexistent          1.1          93.994          -36.4      4.857
# 2      nonexistent          1.1          93.994          -36.4      4.857
# 3      nonexistent          1.1          93.994          -36.4      4.857
# 4      nonexistent          1.1          93.994          -36.4      4.857
# ...            ...          ...             ...            ...        ...
# 41194      failure         -1.1          94.767          -50.8      1.028
# 41195      failure         -1.1          94.767          -50.8      1.028
# 41196      failure         -1.1          94.767          -50.8      1.028
# 41197          NaN          NaN             NaN            NaN        NaN
# 41198      failure         -1.1             NaN          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41194       4963.6   no
# 41195       4963.6   no
# 41196       4963.6   no
# 41197          NaN  NaN
# 41198       4963.6   no
#
# [41199 rows x 21 columns]

# %%
data.head(20)
# Out:
#      age          job   marital            education  default housing loan  \
# 0   56.0    housemaid   married             basic.4y       no      no   no
# 1   57.0     services   married          high.school  unknown      no   no
# 2   37.0     services   married          high.school       no     yes   no
# 3   40.0       admin.   married             basic.6y       no      no   no
# 4   56.0     services   married          high.school       no      no  yes
# 5   45.0     services   married             basic.9y  unknown      no   no
# 6   59.0       admin.   married  professional.course       no      no   no
# 7   41.0  blue-collar   married              unknown  unknown      no   no
# 8   24.0   technician    single  professional.course       no     yes   no
# 9   25.0     services    single          high.school       no     yes   no
# 10  41.0  blue-collar   married              unknown  unknown      no   no
# 11  25.0     services    single          high.school       no     yes   no
# 12  29.0  blue-collar    single          high.school       no      no  yes
# 13  57.0    housemaid  divorced             basic.4y       no     yes   no
# 14  35.0  blue-collar   married             basic.6y       no     yes   no
# 15  54.0      retired   married             basic.9y  unknown     yes  yes
# 16  35.0  blue-collar   married             basic.6y       no     yes   no
# 17  46.0  blue-collar   married             basic.6y  unknown     yes  yes
# 18  50.0  blue-collar   married             basic.9y       no     yes  yes
# 19  39.0   management    single             basic.9y  unknown      no   no
#
#       contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 1   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 2   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 3   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 4   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 5   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 6   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 7   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 8   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 9   telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 10  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 11  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 12  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 13  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 14  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 15  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 16  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 17  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 18  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 19  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0           1.1          93.994          -36.4      4.857       5191.0  no
# 1           1.1          93.994          -36.4      4.857       5191.0  no
# 2           1.1          93.994          -36.4      4.857       5191.0  no
# 3           1.1          93.994          -36.4      4.857       5191.0  no
# 4           1.1          93.994          -36.4      4.857       5191.0  no
# 5           1.1          93.994          -36.4      4.857       5191.0  no
# 6           1.1          93.994          -36.4      4.857       5191.0  no
# 7           1.1          93.994          -36.4      4.857       5191.0  no
# 8           1.1          93.994          -36.4      4.857       5191.0  no
# 9           1.1          93.994          -36.4      4.857       5191.0  no
# 10          1.1          93.994          -36.4      4.857       5191.0  no
# 11          1.1          93.994          -36.4      4.857       5191.0  no
# 12          1.1          93.994          -36.4      4.857       5191.0  no
# 13          1.1          93.994          -36.4      4.857       5191.0  no
# 14          1.1          93.994          -36.4      4.857       5191.0  no
# 15          1.1          93.994          -36.4      4.857       5191.0  no
# 16          1.1          93.994          -36.4      4.857       5191.0  no
# 17          1.1          93.994          -36.4      4.857       5191.0  no
# 18          1.1          93.994          -36.4      4.857       5191.0  no
# 19          1.1          93.994          -36.4      4.857       5191.0  no
#
# [20 rows x 21 columns]

# %%
# to see the how many unique values we are having in job column
data.head(5)
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
data['job'].value_counts()
# Out:
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1726
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %%
data['loan'].value_counts()
# Out:
# loan
# no         33957
# yes         6248
# unknown      990
# Name: count, dtype: int64

# %%
# for all the columns counts
for i in data.columns:
  print(data[i].value_counts())
# Out:
# age
# 31.0    1947
# 32.0    1846
# 33.0    1833
# 36.0    1780
# 35.0    1759
#         ...
# 89.0       2
# 98.0       2
# 91.0       2
# 87.0       1
# 95.0       1
# Name: count, Length: 78, dtype: int64
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1726
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64
# marital
# married     24934
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5249
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64
# default
# no         32595
# unknown     8597
# yes            3
# Name: count, dtype: int64
# housing
# yes        21584
# no         18622
# unknown      990
# Name: count, dtype: int64
# loan
# no         33957
# yes         6248
# unknown      990
# Name: count, dtype: int64
# contact
# cellular     26151
# telephone    15044
# Name: count, dtype: int64
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4109
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64
# day_of_week
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7835
# Name: count, dtype: int64
# duration
# 90.0      170
# 85.0      170
# 136.0     168
# 73.0      167
# 124.0     164
#          ...
# 1569.0      1
# 1053.0      1
# 1263.0      1
# 1169.0      1
# 1868.0      1
# Name: count, Length: 1544, dtype: int64
# campaign
# 1.0     17642
# 2.0     10570
# 3.0      5349
# 4.0      2651
# 5.0      1599
# 6.0       979
# 7.0       629
# 8.0       400
# 9.0       283
# 10.0      225
# 11.0      177
# 12.0      125
# 13.0       92
# 14.0       69
# 17.0       58
# 16.0       51
# 15.0       51
# 18.0       33
# 20.0       30
# 19.0       26
# 21.0       24
# 22.0       17
# 23.0       16
# 24.0       15
# 27.0       11
# 29.0       10
# 28.0        8
# 26.0        8
# 25.0        8
# 31.0        7
# 30.0        7
# 35.0        5
# 32.0        4
# 33.0        4
# 34.0        3
# 42.0        2
# 40.0        2
# 43.0        2
# 56.0        1
# 39.0        1
# 41.0        1
# 37.0        1
# Name: count, dtype: int64
# pdays
# 999.0    39681
# 3.0        439
# 6.0        412
# 4.0        118
# 9.0         64
# 2.0         61
# 7.0         60
# 12.0        58
# 10.0        52
# 5.0         46
# 13.0        36
# 11.0        28
# 1.0         26
# 15.0        24
# 14.0        20
# 8.0         18
# 0.0         15
# 16.0        11
# 17.0         8
# 18.0         7
# 22.0         3
# 19.0         3
# 21.0         2
# 25.0         1
# 26.0         1
# 27.0         1
# 20.0         1
# Name: count, dtype: int64
# previous
# 0.0    35563
# 1.0     4569
# 2.0      754
# 3.0      216
# 4.0       70
# 5.0       18
# 6.0        5
# 7.0        1
# Name: count, dtype: int64
# poutcome
# nonexistent    35563
# failure         4258
# success         1373
# Name: count, dtype: int64
# emp.var.rate
#  1.4    16234
# -1.8     9184
#  1.1     7763
# -0.1     3683
# -2.9     1663
# -3.4     1071
# -1.7      773
# -1.1      643
# -3.0      172
# -0.2       10
# Name: count, dtype: int64
# cons.price.idx
# 93.994    7763
# 93.918    6685
# 92.893    5794
# 93.444    5175
# 94.465    4374
# 93.200    3616
# 93.075    2458
# 92.201     770
# 92.963     715
# 92.431     447
# 92.649     357
# 94.215     311
# 94.199     303
# 92.843     282
# 92.379     267
# 93.369     264
# 94.027     233
# 94.055     229
# 93.876     212
# 94.601     204
# 92.469     178
# 93.749     174
# 92.713     172
# 94.767     135
# 93.798      67
# 92.756      10
# Name: count, dtype: int64
# cons.conf.idx
# -36.4    7763
# -42.7    6685
# -46.2    5794
# -36.1    5175
# -41.8    4374
# -42.0    3616
# -47.1    2458
# -31.4     770
# -40.8     715
# -26.9     447
# -30.1     357
# -40.3     311
# -37.5     303
# -50.0     282
# -29.8     267
# -34.8     264
# -38.3     233
# -39.8     229
# -40.0     212
# -49.5     204
# -33.6     178
# -34.6     174
# -33.0     172
# -50.8     136
# -40.4      67
# -45.9      10
# Name: count, dtype: int64
# euribor3m
# 4.857    2868
# 4.962    2613
# 4.963    2487
# 4.961    1902
# 4.856    1210
#          ...
# 0.933       1
# 1.574       1
# 3.329       1
# 3.853       1
# 0.969       1
# Name: count, Length: 316, dtype: int64
# nr.employed
# 5228.1    16234
# 5099.1     8534
# 5191.0     7763
# 5195.8     3683
# 5076.2     1663
# 5017.5     1071
# 4991.6      773
# 5008.7      650
# 4963.6      643
# 5023.5      172
# 5176.3       10
# Name: count, dtype: int64
# y
# no     36556
# yes     4640
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (41199, 21)

# %%
# summary of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41195 non-null  float64
#  1   job             41194 non-null  object
#  2   marital         41194 non-null  object
#  3   education       41194 non-null  object
#  4   default         41195 non-null  object
#  5   housing         41196 non-null  object
#  6   loan            41195 non-null  object
#  7   contact         41195 non-null  object
#  8   month           41196 non-null  object
#  9   day_of_week     41196 non-null  object
#  10  duration        41196 non-null  float64
#  11  campaign        41196 non-null  float64
#  12  pdays           41196 non-null  float64
#  13  previous        41196 non-null  float64
#  14  poutcome        41194 non-null  object
#  15  emp.var.rate    41196 non-null  float64
#  16  cons.price.idx  41195 non-null  float64
#  17  cons.conf.idx   41196 non-null  float64
#  18  euribor3m       41196 non-null  float64
#  19  nr.employed     41196 non-null  float64
#  20  y               41196 non-null  object
# dtypes: float64(10), object(11)
# memory usage: 6.6+ MB

# %%
data.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  41195.000000  41196.000000  41196.000000  41196.000000  41196.000000
# mean      40.030319    258.281265      2.567676    962.482547      0.173124
# std       10.431818    259.254211      2.769751    186.893451      0.494987
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    180.000000      2.000000    999.000000      0.000000
# 75%       47.000000    319.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41196.000000    41195.000000   41196.000000  41196.000000  41196.000000
# mean       0.081656       93.575867     -40.504600      3.620787   5166.996405
# std        1.570894        0.578999       4.629972      1.734655     72.300104
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %%
col_list = list(data.columns)
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'duration',
#  'campaign',
#  'pdays',
#  'previous',
#  'poutcome',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'euribor3m',
#  'nr.employed',
#  'y']

# %%
data.isnull().sum()
data.isna().sum()
# isnull gives counts of nan values
# isna gives counts of nan and empty values
# Out:
# age               4
# job               5
# marital           5
# education         5
# default           4
# housing           3
# loan              4
# contact           4
# month             3
# day_of_week       3
# duration          3
# campaign          3
# pdays             3
# previous          3
# poutcome          5
# emp.var.rate      3
# cons.price.idx    4
# cons.conf.idx     3
# euribor3m         3
# nr.employed       3
# y                 3
# dtype: int64

# %%
# to fill the null values
#data['age'] = data['age'].fillna(data['age'].mean())

# %%
for col in col_list:
  if data[col].dtypes == 'object':
    data[col] = data[col].fillna(data[col].mode()[0])
  else:
      data[col] = data[col].fillna(data[col].mean())

# %%
data.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# target columns
data['y']
# Out:
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
#          ..
# 41194    no
# 41195    no
# 41196    no
# 41197    no
# 41198    no
# Name: y, Length: 41199, dtype: object

# %%
data['y'] = np.where(data['y']=='yes',1,0) # to replace the categorical values by numerical values

# %%
data['y']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41194    0
# 41195    0
# 41196    0
# 41197    0
# 41198    0
# Name: y, Length: 41199, dtype: int64

# %%
data['y'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# #**Boxplot**
# Using boxplot we will be visualizing the outliers,after that we will be using IQR method and handling the outliers.
#
# with the help of boxplot we can visualize that 'age','duration','campaign','cons.conf.idx' columns has a outlier.1

# %%
for col_name in col_list:
  if(data[col_name].dtypes=='int64' or data[col_name].dtypes=='float64'):
    sns.boxplot(data[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %%
#handling the outliers
Q1 = data.age.quantile(0.25)
Q3 = data.age.quantile(0.75)
IQR = Q3-Q1
data = data[(data.age>=Q1-1.5*IQR) & (data.age<= Q3+1.5*IQR)]

Q1 = data.duration.quantile(0.25)
Q3 = data.duration.quantile(0.75)
IQR = Q3-Q1
data = data[(data.duration>=Q1-1.5*IQR) & (data.duration<= Q3+1.5*IQR)]

Q1 = data.campaign.quantile(0.25)
Q3 = data.campaign.quantile(0.75)
IQR = Q3-Q1
data = data[(data.campaign>=Q1-1.5*IQR) & (data.campaign<= Q3+1.5*IQR)]

Q1 = data['cons.conf.idx'].quantile(0.25)
Q3 = data['cons.conf.idx'].quantile(0.75)
IQR = Q3 - Q1
data = data[(data['cons.conf.idx'] >= Q1 - 1.5*IQR) & (data['cons.conf.idx'] <= Q3 + 1.5*IQR)]

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
for col_name in col_list:
    if(data[col_name].dtypes=='int64' or data[col_name].dtypes=='float64'):
        sns.boxplot(data[col_name])
        plt.xlabel(col_name)
        plt.ylabel('count')
        plt.show()

# %%
#feature selection
data.head()
# Out:
#     age        job  marital    education  default housing loan    contact  \
# 0  56.0  housemaid  married     basic.4y       no      no   no  telephone
# 1  57.0   services  married  high.school  unknown      no   no  telephone
# 2  37.0   services  married  high.school       no     yes   no  telephone
# 3  40.0     admin.  married     basic.6y       no      no   no  telephone
# 4  56.0   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 1   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 2   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 3   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
# 4   may         mon  ...       1.0  999.0       0.0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          93.994          -36.4      4.857       5191.0  0
# 1          93.994          -36.4      4.857       5191.0  0
# 2          93.994          -36.4      4.857       5191.0  0
# 3          93.994          -36.4      4.857       5191.0  0
# 4          93.994          -36.4      4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
data['age'].nunique()
# Out:
# 54

# %%
# Binning - grouping the data
bins = [0,50,100]
data['age'] = pd.cut(data['age'],bins)

# %%
data['age']=data['age'].astype(str)

# %%
data.head()
# Out:
#          age        job  marital    education  default housing loan  \
# 0  (50, 100]  housemaid  married     basic.4y       no      no   no
# 1  (50, 100]   services  married  high.school  unknown      no   no
# 2    (0, 50]   services  married  high.school       no     yes   no
# 3    (0, 50]     admin.  married     basic.6y       no      no   no
# 4  (50, 100]   services  married  high.school       no      no  yes
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 1  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 2  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 3  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
# 4  telephone   may         mon  ...       1.0  999.0       0.0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          1.1          93.994          -36.4      4.857       5191.0  0
# 1          1.1          93.994          -36.4      4.857       5191.0  0
# 2          1.1          93.994          -36.4      4.857       5191.0  0
# 3          1.1          93.994          -36.4      4.857       5191.0  0
# 4          1.1          93.994          -36.4      4.857       5191.0  0
#
# [5 rows x 21 columns]

# %%
data['age'].value_counts()
# Out:
# age
# (0, 50]      29414
# (50, 100]     5766
# Name: count, dtype: int64

# %%
data.dtypes
# Out:
# age                object
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration          float64
# campaign          float64
# pdays             float64
# previous          float64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                   int64
# dtype: object

# %%
#One hot encoding
col_list = []
for col in data.columns:
    if ((data[col].dtype == 'object') & (col != 'y' )):
        col_list.append(col)

# %%
col_list
# Out:
# ['age',
#  'job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'day_of_week',
#  'poutcome']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in col_list:
  data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    3        1          0        0        0     0        1      6
# 1        1    7        1          3        1        0     0        1      6
# 2        0    7        1          3        0        2     0        1      6
# 3        0    0        1          1        0        0     0        1      6
# 4        1    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41186    0    9        1          5        0        0     0        0      7
# 41188    0    0        1          6        0        2     0        0      6
# 41189    0    5        1          5        0        2     0        0      7
# 41191    0    0        1          6        0        2     0        0      6
# 41197    0    0        1          6        0        2     0        0      6
#
#        day_of_week  ...  campaign       pdays  previous  poutcome  \
# 0                1  ...  1.000000  999.000000  0.000000         1
# 1                1  ...  1.000000  999.000000  0.000000         1
# 2                1  ...  1.000000  999.000000  0.000000         1
# 3                1  ...  1.000000  999.000000  0.000000         1
# 4                1  ...  1.000000  999.000000  0.000000         1
# ...            ...  ...       ...         ...       ...       ...
# 41186            0  ...  1.000000  999.000000  0.000000         1
# 41188            2  ...  2.567676  962.482547  0.173124         1
# 41189            0  ...  3.000000  999.000000  1.000000         1
# 41191            2  ...  2.567676  962.482547  0.173124         1
# 41197            2  ...  2.567676  962.482547  0.173124         1
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# 0          1.100000       93.994000       -36.4000   4.857000  5191.000000  0
# 1          1.100000       93.994000       -36.4000   4.857000  5191.000000  0
# 2          1.100000       93.994000       -36.4000   4.857000  5191.000000  0
# 3          1.100000       93.994000       -36.4000   4.857000  5191.000000  0
# 4          1.100000       93.994000       -36.4000   4.857000  5191.000000  0
# ...             ...             ...            ...        ...          ... ..
# 41186     -1.100000       94.767000       -50.8000   1.028000  4963.600000  1
# 41188      0.081656       93.575867       -40.5046   3.620787  5166.996405  0
# 41189     -1.100000       94.767000       -50.8000   1.028000  4963.600000  0
# 41191      0.081656       93.575867       -40.5046   3.620787  5166.996405  0
# 41197      0.081656       93.575867       -40.5046   3.620787  5166.996405  0
#
# [35180 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35180 entries, 0 to 41197
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             35180 non-null  int64
#  1   job             35180 non-null  int64
#  2   marital         35180 non-null  int64
#  3   education       35180 non-null  int64
#  4   default         35180 non-null  int64
#  5   housing         35180 non-null  int64
#  6   loan            35180 non-null  int64
#  7   contact         35180 non-null  int64
#  8   month           35180 non-null  int64
#  9   day_of_week     35180 non-null  int64
#  10  duration        35180 non-null  float64
#  11  campaign        35180 non-null  float64
#  12  pdays           35180 non-null  float64
#  13  previous        35180 non-null  float64
#  14  poutcome        35180 non-null  int64
#  15  emp.var.rate    35180 non-null  float64
#  16  cons.price.idx  35180 non-null  float64
#  17  cons.conf.idx   35180 non-null  float64
#  18  euribor3m       35180 non-null  float64
#  19  nr.employed     35180 non-null  float64
#  20  y               35180 non-null  int64
# dtypes: float64(9), int64(12)
# memory usage: 5.9 MB

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#            feature           VIF
# 0              age      1.286060
# 1              job      2.102392
# 2          marital      5.102942
# 3        education      4.554782
# 4          default      1.388186
# 5          housing      2.212579
# 6             loan      1.208186
# 7          contact      2.943659
# 8            month      6.682876
# 9      day_of_week      3.098194
# 10        duration      3.231247
# 11        campaign      3.615616
# 12           pdays    174.888632
# 13        previous      6.069124
# 14        poutcome     34.936794
# 15    emp.var.rate     37.561379
# 16  cons.price.idx  37876.556521
# 17   cons.conf.idx    143.298097
# 18       euribor3m    322.577448
# 19     nr.employed  43153.467668

# %%
X
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    3        1          0        0        0     0        1      6
# 1        1    7        1          3        1        0     0        1      6
# 2        0    7        1          3        0        2     0        1      6
# 3        0    0        1          1        0        0     0        1      6
# 4        1    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41186    0    9        1          5        0        0     0        0      7
# 41188    0    0        1          6        0        2     0        0      6
# 41189    0    5        1          5        0        2     0        0      7
# 41191    0    0        1          6        0        2     0        0      6
# 41197    0    0        1          6        0        2     0        0      6
#
#        day_of_week    duration  campaign       pdays  previous  poutcome  \
# 0                1  261.000000  1.000000  999.000000  0.000000         1
# 1                1  149.000000  1.000000  999.000000  0.000000         1
# 2                1  226.000000  1.000000  999.000000  0.000000         1
# 3                1  151.000000  1.000000  999.000000  0.000000         1
# 4                1  307.000000  1.000000  999.000000  0.000000         1
# ...            ...         ...       ...         ...       ...       ...
# 41186            0  442.000000  1.000000  999.000000  0.000000         1
# 41188            2  258.281265  2.567676  962.482547  0.173124         1
# 41189            0  239.000000  3.000000  999.000000  1.000000         1
# 41191            2  258.281265  2.567676  962.482547  0.173124         1
# 41197            2  258.281265  2.567676  962.482547  0.173124         1
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0          1.100000       93.994000       -36.4000   4.857000  5191.000000
# 1          1.100000       93.994000       -36.4000   4.857000  5191.000000
# 2          1.100000       93.994000       -36.4000   4.857000  5191.000000
# 3          1.100000       93.994000       -36.4000   4.857000  5191.000000
# 4          1.100000       93.994000       -36.4000   4.857000  5191.000000
# ...             ...             ...            ...        ...          ...
# 41186     -1.100000       94.767000       -50.8000   1.028000  4963.600000
# 41188      0.081656       93.575867       -40.5046   3.620787  5166.996405
# 41189     -1.100000       94.767000       -50.8000   1.028000  4963.600000
# 41191      0.081656       93.575867       -40.5046   3.620787  5166.996405
# 41197      0.081656       93.575867       -40.5046   3.620787  5166.996405
#
# [35180 rows x 20 columns]

# %%
data=data.drop(['nr.employed'], axis = 1)

# %%
data=data.drop(['cons.price.idx'], axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age   1.277992
# 1             job   2.096725
# 2         marital   5.056380
# 3       education   4.504406
# 4         default   1.383641
# 5         housing   2.210468
# 6            loan   1.207580
# 7         contact   2.347943
# 8           month   5.707940
# 9     day_of_week   3.084723
# 10       duration   3.194917
# 11       campaign   3.584662
# 12          pdays  91.987197
# 13       previous   2.892758
# 14       poutcome  16.724093
# 15   emp.var.rate  16.142019
# 16  cons.conf.idx  82.493011
# 17      euribor3m  90.370371

# %%
data=data.drop(['euribor3m'], axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#           feature        VIF
# 0             age   1.274295
# 1             job   2.095542
# 2         marital   5.055200
# 3       education   4.467347
# 4         default   1.383506
# 5         housing   2.208728
# 6            loan   1.207535
# 7         contact   2.342480
# 8           month   5.294187
# 9     day_of_week   3.074420
# 10       duration   3.194599
# 11       campaign   3.584604
# 12          pdays  56.212091
# 13       previous   2.435493
# 14       poutcome  11.727950
# 15   emp.var.rate   1.635351
# 16  cons.conf.idx  81.910927

# %%
data=data.drop(['cons.conf.idx'], axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#          feature        VIF
# 0            age   1.271702
# 1            job   2.095493
# 2        marital   5.044991
# 3      education   4.450421
# 4        default   1.382155
# 5        housing   2.206934
# 6           loan   1.207071
# 7        contact   2.244982
# 8          month   5.218381
# 9    day_of_week   3.074413
# 10      duration   3.190672
# 11      campaign   3.566328
# 12         pdays  14.287739
# 13      previous   1.584097
# 14      poutcome   6.646963
# 15  emp.var.rate   1.539385

# %%
data=data.drop(['poutcome'], axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list = []
for col in data.columns:
    if ((data[col].dtype != 'object') & (col != 'y') ):
        col_list.append(col)

X = data[col_list]
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(len(X.columns))]
vif_data
# Out:
#          feature        VIF
# 0            age   1.251629
# 1            job   2.077488
# 2        marital   4.764909
# 3      education   4.216243
# 4        default   1.374910
# 5        housing   2.174491
# 6           loan   1.205008
# 7        contact   2.228572
# 8          month   5.092136
# 9    day_of_week   2.986351
# 10      duration   3.036958
# 11      campaign   3.439525
# 12         pdays  14.274706
# 13      previous   1.503495
# 14  emp.var.rate   1.530228

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    3        1          0        0        0     0        1      6
# 1        1    7        1          3        1        0     0        1      6
# 2        0    7        1          3        0        2     0        1      6
# 3        0    0        1          1        0        0     0        1      6
# 4        1    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41186    0    9        1          5        0        0     0        0      7
# 41188    0    0        1          6        0        2     0        0      6
# 41189    0    5        1          5        0        2     0        0      7
# 41191    0    0        1          6        0        2     0        0      6
# 41197    0    0        1          6        0        2     0        0      6
#
#        day_of_week    duration  campaign       pdays  previous  emp.var.rate  \
# 0                1  261.000000  1.000000  999.000000  0.000000      1.100000
# 1                1  149.000000  1.000000  999.000000  0.000000      1.100000
# 2                1  226.000000  1.000000  999.000000  0.000000      1.100000
# 3                1  151.000000  1.000000  999.000000  0.000000      1.100000
# 4                1  307.000000  1.000000  999.000000  0.000000      1.100000
# ...            ...         ...       ...         ...       ...           ...
# 41186            0  442.000000  1.000000  999.000000  0.000000     -1.100000
# 41188            2  258.281265  2.567676  962.482547  0.173124      0.081656
# 41189            0  239.000000  3.000000  999.000000  1.000000     -1.100000
# 41191            2  258.281265  2.567676  962.482547  0.173124      0.081656
# 41197            2  258.281265  2.567676  962.482547  0.173124      0.081656
#
#        y
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 41186  1
# 41188  0
# 41189  0
# 41191  0
# 41197  0
#
# [35180 rows x 16 columns]

# %%
Ind_features = list(data.columns)
Ind_features.remove('y')

x = data[Ind_features] #features
y = data['y'] #target variable

# %%
x
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0        1    3        1          0        0        0     0        1      6
# 1        1    7        1          3        1        0     0        1      6
# 2        0    7        1          3        0        2     0        1      6
# 3        0    0        1          1        0        0     0        1      6
# 4        1    7        1          3        0        0     2        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41186    0    9        1          5        0        0     0        0      7
# 41188    0    0        1          6        0        2     0        0      6
# 41189    0    5        1          5        0        2     0        0      7
# 41191    0    0        1          6        0        2     0        0      6
# 41197    0    0        1          6        0        2     0        0      6
#
#        day_of_week    duration  campaign       pdays  previous  emp.var.rate
# 0                1  261.000000  1.000000  999.000000  0.000000      1.100000
# 1                1  149.000000  1.000000  999.000000  0.000000      1.100000
# 2                1  226.000000  1.000000  999.000000  0.000000      1.100000
# 3                1  151.000000  1.000000  999.000000  0.000000      1.100000
# 4                1  307.000000  1.000000  999.000000  0.000000      1.100000
# ...            ...         ...       ...         ...       ...           ...
# 41186            0  442.000000  1.000000  999.000000  0.000000     -1.100000
# 41188            2  258.281265  2.567676  962.482547  0.173124      0.081656
# 41189            0  239.000000  3.000000  999.000000  1.000000     -1.100000
# 41191            2  258.281265  2.567676  962.482547  0.173124      0.081656
# 41197            2  258.281265  2.567676  962.482547  0.173124      0.081656
#
# [35180 rows x 15 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41186    1
# 41188    0
# 41189    0
# 41191    0
# 41197    0
# Name: y, Length: 35180, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.75, random_state=898)

# %%
x_train
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 12633    0    7        2          3        0        0     0        0      3
# 11783    0    7        1          3        0        0     0        1      4
# 21973    0    0        2          6        0        0     2        0      1
# 31978    0    9        2          5        0        0     2        0      6
# 14895    0    2        1          5        0        2     0        0      3
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 33418    0    1        1          2        0        2     2        0      6
# 5676     1    4        1          6        0        0     2        1      6
# 20285    0    0        2          6        0        0     2        0      1
# 246      0    9        2          5        0        0     0        1      6
# 12408    0    4        1          7        0        0     2        0      3
#
#        day_of_week  duration  campaign  pdays  previous  emp.var.rate
# 12633            1      98.0       1.0  999.0       0.0           1.4
# 11783            0      55.0       2.0  999.0       0.0           1.4
# 21973            4     447.0       2.0  999.0       0.0           1.4
# 31978            2     181.0       2.0  999.0       1.0          -1.8
# 14895            4     157.0       2.0  999.0       0.0           1.4
# ...            ...       ...       ...    ...       ...           ...
# 33418            3      31.0       4.0  999.0       0.0          -1.8
# 5676             1     312.0       1.0  999.0       0.0           1.1
# 20285            1     312.0       3.0  999.0       0.0           1.4
# 246              1      79.0       1.0  999.0       0.0           1.1
# 12408            1      86.0       2.0  999.0       0.0           1.4
#
# [26385 rows x 15 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
logisticRegr = LogisticRegression()

# %%
#####Model Fitting/Training###
logisticRegr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
test_pred = logisticRegr.predict(x_test)

# %%
test_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pred = pd.DataFrame()
pred["y_test"] = y_test #actual answer key
pred["y_pred"] = test_pred #answers given by model
pred
# Out:
#        y_test  y_pred
# 22300       0       0
# 32905       0       0
# 38983       0       0
# 11265       0       0
# 34001       1       0
# ...       ...     ...
# 31659       0       0
# 10522       0       0
# 40316       0       0
# 40009       0       0
# 34892       0       0
#
# [8795 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,test_pred)
# Out:
# 0.9295054007959067

# %%
confusion_matrix(y_test,test_pred)
# Out:
# array([[7961,  137],
#        [ 483,  214]])

# %%
recall = 8008/(8008+566)
precision = 8008/(8008+90)
accuracy = (8008 + 131)/(8008+90+566+131)
